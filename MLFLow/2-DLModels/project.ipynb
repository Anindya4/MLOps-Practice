# %% [markdown]
# ## Deep Learning Models with MLFLow

# %%
import keras
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from mlflow.models import infer_signature
import mlflow
from hyperopt import hp, tpe, Trials, STATUS_OK, fmin
# Out:
# 2025-11-26 03:50:20.319145: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 03:50:20.379697: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 03:50:22.335313: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
data = pd.read_csv("DATA/winequality-red.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# ##### Spliting the data into train, test, validation

# %%
train,test=train_test_split(data, test_size=0.25,random_state=42)

train_x=train.drop(["quality"], axis=1).values
train_y=train[["quality"]].values.ravel()


## Testing data:
test_x=test.drop(["quality"],axis=1).values
test_y=test[["quality"]].values.ravel()


## Validation data from train data:
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.20, random_state=42)


## Infer-Signature:
signature=infer_signature(train_x, train_y)

# %%
train_x.shape[1]
# Out:
# 11

# %%
# Build the ANN:
def train_model(train_x, train_y, test_x, test_y, val_x, val_y, epochs, params):
    
    ## Define model architecture:
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)
    
    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean, variance=var),
            keras.layers.Dense(64, activation="relu"),
            keras.layers.Dense(1)
        ]
    )
    
    ## Compile the model:
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params['lr'],
        momentum=params["momentum"],
    ),
    loss=keras.losses.mean_squared_error,
    metrics=[keras.metrics.RootMeanSquaredError()]
    )
    
    ## Train the model:
    with mlflow.start_run(nested=True):
        model.fit(train_x, train_y, validation_data=(val_x,val_y), batch_size=64, epochs=epochs)
        
        ## Evaluate the model:
        eval_result=model.evaluate(val_x,val_y,batch_size=64)
        eval_rmse=eval_result[1]
        
        
        ## Log the results and metrics:
        mlflow.log_params(params=params)
        mlflow.log_metric("rmse", eval_rmse)
        
        
        ## Log the model:
        mlflow.tensorflow.log_model(
            model=model,
            artifact_path="model_tf-SGD",
            signature=signature
        )
        
        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    result = train_model(
        train_x=train_x,
        train_y=train_y,
        test_x=test_x,
        test_y=test_y,
        val_x=val_x,
        val_y=val_y,
        epochs=10,
        params=params
    )
    return result

# %%
spaces = {
    "lr": hp.loguniform("lr", np.log(1e-5), np.log(1e-1)),
    "momentum": hp.uniform("momentum", 0.0, 1.0)
}

# %%
mlflow.set_experiment("wine-quality-SGD")
with mlflow.start_run():
    trial=Trials()
    best=fmin(
        fn=objective,
        algo=tpe.suggest,
        space=spaces,
        max_evals=4,
        trials=trial
    )
    
    # Fetch the details of the best runs:
    best_run=sorted(trial.results, key=lambda x:x["loss"])[0]
    
    mlflow.log_params(best)
    mlflow.log_metric("rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model_tf", signature=signature)
# Out:
# /home/anindya/projects/MLOps_Udemy/udemy_mlops/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/utils.py:140: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, store_uri)
# 2025/11/26 03:50:25 INFO mlflow.tracking.fluent: Experiment with name 'wine-quality-SGD' does not exist. Creating a new experiment.
#   0%|          | 0/4 [00:00<?, ?trial/s, best loss=?]
# 2025-11-26 03:50:25.505575: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 5s 379ms/step - loss: 32.0523 - root_mean_squared_error: 5.6615
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.2728 - root_mean_squared_error: 3.2051 - val_loss: 2.5018 - val_root_mean_squared_error: 1.5817
#
# Epoch 2/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1404 - root_mean_squared_error: 1.4630
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7807 - root_mean_squared_error: 1.3344 - val_loss: 1.4681 - val_root_mean_squared_error: 1.2116
#
# Epoch 3/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2472 - root_mean_squared_error: 1.1168
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1873 - root_mean_squared_error: 1.0896 - val_loss: 1.1444 - val_root_mean_squared_error: 1.0698
#
# Epoch 4/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9229 - root_mean_squared_error: 0.9607
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9812 - root_mean_squared_error: 0.9905 - val_loss: 1.0168 - val_root_mean_squared_error: 1.0084
#
# Epoch 5/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7662 - root_mean_squared_error: 0.8753
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8726 - root_mean_squared_error: 0.9341 - val_loss: 0.9378 - val_root_mean_squared_error: 0.9684
#
# Epoch 6/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.7889 - root_mean_squared_error: 0.8882
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7892 - root_mean_squared_error: 0.8884 - val_loss: 0.8603 - val_root_mean_squared_error: 0.9275
#
# Epoch 7/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7515 - root_mean_squared_error: 0.8669
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7270 - root_mean_squared_error: 0.8526 - val_loss: 0.8111 - val_root_mean_squared_error: 0.9006
#
# Epoch 8/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6486 - root_mean_squared_error: 0.8053
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6799 - root_mean_squared_error: 0.8246 - val_loss: 0.7740 - val_root_mean_squared_error: 0.8798
#
# Epoch 9/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7897 - root_mean_squared_error: 0.8887
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6375 - root_mean_squared_error: 0.7984 - val_loss: 0.7551 - val_root_mean_squared_error: 0.8690
#
# Epoch 10/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6288 - root_mean_squared_error: 0.7930
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6035 - root_mean_squared_error: 0.7768 - val_loss: 0.7138 - val_root_mean_squared_error: 0.8449
#
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6474 - root_mean_squared_error: 0.8046
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7138 - root_mean_squared_error: 0.8449
#
#   0%|          | 0/4 [00:01<?, ?trial/s, best loss=?]
# 2025/11/26 03:50:27 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Epoch 1/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 27.7969 - root_mean_squared_error: 5.2723
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 29.5032 - root_mean_squared_error: 5.4317 - val_loss: 27.9556 - val_root_mean_squared_error: 5.2873
#
# Epoch 2/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 28.0814 - root_mean_squared_error: 5.2992
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.4979 - root_mean_squared_error: 5.3383 - val_loss: 26.9609 - val_root_mean_squared_error: 5.1924
#
# Epoch 3/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 29.5073 - root_mean_squared_error: 5.4321
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.4929 - root_mean_squared_error: 5.2434 - val_loss: 26.0024 - val_root_mean_squared_error: 5.0993
#
# Epoch 4/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 25.6233 - root_mean_squared_error: 5.0619
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.5235 - root_mean_squared_error: 5.1501 - val_loss: 25.0815 - val_root_mean_squared_error: 5.0081
#
# Epoch 5/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 27.1778 - root_mean_squared_error: 5.2132
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.5914 - root_mean_squared_error: 5.0588 - val_loss: 24.1869 - val_root_mean_squared_error: 4.9180
#
# Epoch 6/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 23.7142 - root_mean_squared_error: 4.8697
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.6891 - root_mean_squared_error: 4.9688 - val_loss: 23.3267 - val_root_mean_squared_error: 4.8298
#
# Epoch 7/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 25.0939 - root_mean_squared_error: 5.0094
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.8184 - root_mean_squared_error: 4.8804 - val_loss: 22.4956 - val_root_mean_squared_error: 4.7430
#
# Epoch 8/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 23.5153 - root_mean_squared_error: 4.8493
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.9787 - root_mean_squared_error: 4.7936 - val_loss: 21.6887 - val_root_mean_squared_error: 4.6571
#
# Epoch 9/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 22.8357 - root_mean_squared_error: 4.7787
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.1642 - root_mean_squared_error: 4.7079 - val_loss: 20.9158 - val_root_mean_squared_error: 4.5734
#
# Epoch 10/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.9660 - root_mean_squared_error: 4.4683
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.3791 - root_mean_squared_error: 4.6237 - val_loss: 20.1667 - val_root_mean_squared_error: 4.4907
#
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 20.1640 - root_mean_squared_error: 4.4904
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.1667 - root_mean_squared_error: 4.4907
#
#  25%|██▌       | 1/4 [00:07<00:19,  6.62s/trial, best loss: 0.8448653817176819]
# 2025/11/26 03:50:33 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Epoch 1/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - loss: 38.1439 - root_mean_squared_error: 6.1761
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.2462 - root_mean_squared_error: 4.4996 - val_loss: 7.3197 - val_root_mean_squared_error: 2.7055
#
# Epoch 2/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.3491 - root_mean_squared_error: 2.7109
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5148 - root_mean_squared_error: 2.1248 - val_loss: 2.7650 - val_root_mean_squared_error: 1.6628
#
# Epoch 3/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.8198 - root_mean_squared_error: 1.6792
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1990 - root_mean_squared_error: 1.4829 - val_loss: 1.9439 - val_root_mean_squared_error: 1.3942
#
# Epoch 4/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6719 - root_mean_squared_error: 1.2930
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6324 - root_mean_squared_error: 1.2776 - val_loss: 1.5821 - val_root_mean_squared_error: 1.2578
#
# Epoch 5/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6523 - root_mean_squared_error: 1.2854
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3498 - root_mean_squared_error: 1.1618 - val_loss: 1.3922 - val_root_mean_squared_error: 1.1799
#
# Epoch 6/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9101 - root_mean_squared_error: 0.9540
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1958 - root_mean_squared_error: 1.0935 - val_loss: 1.2693 - val_root_mean_squared_error: 1.1266
#
# Epoch 7/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1781 - root_mean_squared_error: 1.0854
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0891 - root_mean_squared_error: 1.0436 - val_loss: 1.1875 - val_root_mean_squared_error: 1.0897
#
# Epoch 8/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3064 - root_mean_squared_error: 1.1430
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0191 - root_mean_squared_error: 1.0095 - val_loss: 1.1308 - val_root_mean_squared_error: 1.0634
#
# Epoch 9/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8796 - root_mean_squared_error: 0.9379
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9586 - root_mean_squared_error: 0.9791 - val_loss: 1.0817 - val_root_mean_squared_error: 1.0401
#
# Epoch 10/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8876 - root_mean_squared_error: 0.9421
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9088 - root_mean_squared_error: 0.9533 - val_loss: 1.0396 - val_root_mean_squared_error: 1.0196
#
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0253 - root_mean_squared_error: 1.0126
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0396 - root_mean_squared_error: 1.0196
#
#  50%|█████     | 2/4 [00:13<00:11,  5.97s/trial, best loss: 0.8448653817176819]
# 2025/11/26 03:50:38 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Epoch 1/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 3s 276ms/step - loss: 35.0344 - root_mean_squared_error: 5.9190
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 29.9144 - root_mean_squared_error: 5.4694 - val_loss: 22.2116 - val_root_mean_squared_error: 4.7129
#
# Epoch 2/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.1674 - root_mean_squared_error: 4.8133
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9902 - root_mean_squared_error: 4.2415 - val_loss: 13.2513 - val_root_mean_squared_error: 3.6402
#
# Epoch 3/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 14.2923 - root_mean_squared_error: 3.7805
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7758 - root_mean_squared_error: 3.2827 - val_loss: 7.8644 - val_root_mean_squared_error: 2.8044
#
# Epoch 4/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.8093 - root_mean_squared_error: 2.7945
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5681 - root_mean_squared_error: 2.5628 - val_loss: 4.8644 - val_root_mean_squared_error: 2.2055
#
# Epoch 5/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.0421 - root_mean_squared_error: 2.2455
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2543 - root_mean_squared_error: 2.0626 - val_loss: 3.2871 - val_root_mean_squared_error: 1.8130
#
# Epoch 6/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.2693 - root_mean_squared_error: 1.8081
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0260 - root_mean_squared_error: 1.7395 - val_loss: 2.4901 - val_root_mean_squared_error: 1.5780
#
# Epoch 7/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0429 - root_mean_squared_error: 1.7444
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3655 - root_mean_squared_error: 1.5380 - val_loss: 2.0698 - val_root_mean_squared_error: 1.4387
#
# Epoch 8/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6358 - root_mean_squared_error: 1.2790
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9816 - root_mean_squared_error: 1.4077 - val_loss: 1.8274 - val_root_mean_squared_error: 1.3518
#
# Epoch 9/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8717 - root_mean_squared_error: 1.3681
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7330 - root_mean_squared_error: 1.3164 - val_loss: 1.6709 - val_root_mean_squared_error: 1.2927
#
# Epoch 10/10
#
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5681 - root_mean_squared_error: 1.2522
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5641 - root_mean_squared_error: 1.2506 - val_loss: 1.5553 - val_root_mean_squared_error: 1.2471
#
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5373 - root_mean_squared_error: 1.2399
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5553 - root_mean_squared_error: 1.2471
#
#  75%|███████▌  | 3/4 [00:18<00:05,  5.70s/trial, best loss: 0.8448653817176819]
# 2025/11/26 03:50:44 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 100%|██████████| 4/4 [00:23<00:00,  5.75s/trial, best loss: 0.8448653817176819]
# 2025/11/26 03:50:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
